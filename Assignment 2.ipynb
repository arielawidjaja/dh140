# %% [markdown]
# # Assignment 2
# ### Ariel Widjaja
# Link to dataset: https://corgis-edu.github.io/corgis/python/video_games/
#
# Basic description of the data: this dataset includes the length of time a video game is played and sales data. This is used to estimate sales in the future.

# %%
import video_games
video_game = video_games.get_video_game()

# %%
video_game
# Out:
# [{'Title': 'Super Mario 64 DS',
#   'Features': {'Handheld?': True,
#    'Max Players': 1,
#    'Multiplatform?': True,
#    'Online?': True},
#   'Metadata': {'Genres': 'Action',
#    'Licensed?': True,
#    'Publishers': 'Nintendo',
#    'Sequel?': True},
#   'Metrics': {'Review Score': 85, 'Sales': 4.69, 'Used Price': 24.95},
#   'Release': {'Console': 'Nintendo DS',
#    'Rating': 'E',
#    'Re-release?': True,
#    'Year': 2004},
#   'Length': {'All PlayStyles': {'Average': 22.716666666666665,
#     'Leisure': 31.9,
#     'Median': 24.483333333333334,
#     'Polled': 57,
#     'Rushed': 14.3},
#    'Completionists': {'Average': 29.766666666666666,
#     'Leisure': 35.03333333333333,
#     'Median': 30.0,
#     'Polled': 20,
#     'Rushed': 22.016666666666666},
#    'Main + Extras': {'Average': 24.916666666666668,
#     'Leisure': 29.966666666666665,
#     'Median': 25.0,
#     'Polled': 16,
#     'Rushed': 18.333333333333332},
#    'Main Story': {'Average': 14.333333333333334,
# ...

# %%
from pprint import pprint as prettyprint

# %%
#Makes it easy to see path
prettyprint(video_game[0])
# Out:
# {'Features': {'Handheld?': True,
#               'Max Players': 1,
#               'Multiplatform?': True,
#               'Online?': True},
#  'Length': {'All PlayStyles': {'Average': 22.716666666666665,
#                                'Leisure': 31.9,
#                                'Median': 24.483333333333334,
#                                'Polled': 57,
#                                'Rushed': 14.3},
#             'Completionists': {'Average': 29.766666666666666,
#                                'Leisure': 35.03333333333333,
#                                'Median': 30.0,
#                                'Polled': 20,
#                                'Rushed': 22.016666666666666},
#             'Main + Extras': {'Average': 24.916666666666668,
#                               'Leisure': 29.966666666666665,
#                               'Median': 25.0,
#                               'Polled': 16,
#                               'Rushed': 18.333333333333332},
# ...

# %%
for i in video_game:
    print(str(i['Title']+':'+i['Metadata']['Publishers']+','+i['Release']['Rating']))
# Out:
# Super Mario 64 DS:Nintendo,E
# Lumines: Puzzle Fusion:Ubisoft,E
# WarioWare Touched!:Nintendo,E
# Hot Shots Golf: Open Tee:Sony,E
# Spider-Man 2:Activision,E
# The Urbz: Sims in the City:EA,M
# Ridge Racer:Namco,E
# Metal Gear Ac!d:Konami,E
# Madden NFL 2005:EA,T
# Pokmon Dash:Nintendo,T
# Dynasty Warriors:,E
# Feel the Magic XY/XX:Sega,T
# Ridge Racer DS:Namco,E
# Darkstalkers Chronicle: The Chaos Tower:Capcom,E
# Ape Escape Academy:Sony,E
# Polarium:Nintendo,E
# Asphalt: Urban GT:Ubisoft,E
# Zoo Keeper:,T
# Mr. DRILLER: Drill Spirits:Namco,T
# Sprung:Ubisoft,E
# Armored Core: Formula Front - Extreme Battle:,E
# Puyo Pop Fever:Sega,E
# Mario Kart DS:Nintendo,E
# Nintendogs:Nintendo,E
# Brain Age: Train Your Brain in Minutes a Day!:Nintendo,M
# Brain Agey: More Training in Minutes a Day!:Nintendo,E
# Grand Theft Auto: Liberty City Stories:Capcom,Rockstar,E
# Animal Crossing: Wild World:Nintendo,T
# Big Brain Academy:Nintendo,E
# Call of Duty 2:Activision,Konami,E
# ...

# %%
a = video_game[5]['Title']
b = video_game[5]['Metadata']['Publishers']
c = video_game[5]['Metrics']['Review Score']
if c > 75:
    print(a + ' by ' + b + ' is a good game!')

# %%
if c > 75:
    print(a + ' by ' + b + ' is a good game!')
elif c == 75:
    print(a + ' by ' + b + ' is a decent game!')
elif c < 75:
    print('Maybe you should not get ' + a + ' by ' + b +'.')
# Out:
# Maybe you should not get The Urbz: Sims in the City by EA.

# %%
gaming = "A time consuming way to get by the day!"

# %%
for letter in gaming:
    print(letter)
# Out:
# A
#
# t
# i
# m
# e
#
# c
# o
# n
# s
# u
# m
# i
# n
# g
#
# w
# a
# y
#
# t
# o
#
# g
# e
# t
#
# b
# y
#
# t
# h
# e
#
# d
# a
# y
# !

# %%
def f(a):
    return a/100

# %%
f(10)
# Out:
# 0.1
