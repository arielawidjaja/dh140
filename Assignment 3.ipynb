# %% [markdown]
# # Assignment 3

# %% [markdown]
# ## Pandas and plotting exercises

# %%
# Import the pandas library

import pandas as pd

# %% [markdown]
# In Week 2, you used a dataset from the CORGIS website.  You may have used either the Python, CSV, or JSON data files.
#
# For this assignment, use the CSV file format for the same category of data that you used previously.

# %%
# Use pandas read_csv function to import the data into a dataframe variable

import video_games
video_game = video_games.get_video_game()

video_game_df = pd.read_csv('video_games.csv')

# %%
# How many rows and columns does the dataframe have?

video_game_df.shape
# Out:
# (1212, 36)

# %%
# What are the column names of the dataframe?

video_game_df.columns
# Out:
# Index(['Title', 'Features.Handheld?', 'Features.Max Players',
#        'Features.Multiplatform?', 'Features.Online?', 'Metadata.Genres',
#        'Metadata.Licensed?', 'Metadata.Publishers', 'Metadata.Sequel?',
#        'Metrics.Review Score', 'Metrics.Sales', 'Metrics.Used Price',
#        'Release.Console', 'Release.Rating', 'Release.Re-release?',
#        'Release.Year', 'Length.All PlayStyles.Average',
#        'Length.All PlayStyles.Leisure', 'Length.All PlayStyles.Median',
#        'Length.All PlayStyles.Polled', 'Length.All PlayStyles.Rushed',
#        'Length.Completionists.Average', 'Length.Completionists.Leisure',
#        'Length.Completionists.Median', 'Length.Completionists.Polled',
#        'Length.Completionists.Rushed', 'Length.Main + Extras.Average',
#        'Length.Main + Extras.Leisure', 'Length.Main + Extras.Median',
#        'Length.Main + Extras.Polled', 'Length.Main + Extras.Rushed',
#        'Length.Main Story.Average', 'Length.Main Story.Leisure',
#        'Length.Main Story.Median', 'Length.Main Story.Polled',
#        'Length.Main Story.Rushed'],
#       dtype='object')

# %%
# What are the datatypes of each column?

video_game_df.dtypes
# Out:
# Title                             object
# Features.Handheld?                  bool
# Features.Max Players               int64
# Features.Multiplatform?             bool
# Features.Online?                    bool
# Metadata.Genres                   object
# Metadata.Licensed?                  bool
# Metadata.Publishers               object
# Metadata.Sequel?                    bool
# Metrics.Review Score               int64
# Metrics.Sales                    float64
# Metrics.Used Price               float64
# Release.Console                   object
# Release.Rating                    object
# Release.Re-release?                 bool
# Release.Year                       int64
# Length.All PlayStyles.Average    float64
# Length.All PlayStyles.Leisure    float64
# Length.All PlayStyles.Median     float64
# Length.All PlayStyles.Polled       int64
# Length.All PlayStyles.Rushed     float64
# Length.Completionists.Average    float64
# Length.Completionists.Leisure    float64
# Length.Completionists.Median     float64
# Length.Completionists.Polled       int64
# Length.Completionists.Rushed     float64
# Length.Main + Extras.Average     float64
# Length.Main + Extras.Leisure     float64
# Length.Main + Extras.Median      float64
# Length.Main + Extras.Polled        int64
# Length.Main + Extras.Rushed      float64
# Length.Main Story.Average        float64
# Length.Main Story.Leisure        float64
# Length.Main Story.Median         float64
# Length.Main Story.Polled           int64
# Length.Main Story.Rushed         float64
# dtype: object

# %%
# Look at the first 2 rows of the dataframe

video_game_df.head(2)
# Out:
#                     Title  Features.Handheld?  Features.Max Players  \
# 0       Super Mario 64 DS                True                     1
# 1  Lumines: Puzzle Fusion                True                     1
#
#    Features.Multiplatform?  Features.Online? Metadata.Genres  \
# 0                     True              True          Action
# 1                     True              True        Strategy
#
#    Metadata.Licensed? Metadata.Publishers  Metadata.Sequel?  \
# 0                True            Nintendo              True
# 1                True             Ubisoft              True
#
#    Metrics.Review Score  ...  Length.Main + Extras.Average  \
# 0                    85  ...                     24.916667
# 1                    89  ...                      9.750000
#
#    Length.Main + Extras.Leisure Length.Main + Extras.Median  \
# 0                     29.966667                       25.00
# 1                      9.866667                        9.75
#
#   Length.Main + Extras.Polled  Length.Main + Extras.Rushed  \
# 0                          16                    18.333333
# 1                           2                     9.616667
#
#    Length.Main Story.Average  Length.Main Story.Leisure  \
# 0                  14.333333                  18.316667
# 1                  10.333333                  11.083333
#
#    Length.Main Story.Median  Length.Main Story.Polled  \
# 0                      14.5                        21
# 1                      10.0                         3
#
#    Length.Main Story.Rushed
# 0                  9.700000
# 1                  9.583333
#
# [2 rows x 36 columns]

# %%
# Look at the last 2 rows of the dataframe

video_game_df.tail(2)
# Out:
#                        Title  Features.Handheld?  Features.Max Players  \
# 1210  Secret Files: Tunguska                True                     2
# 1211          Chicken Hunter                True                     1
#
#       Features.Multiplatform?  Features.Online? Metadata.Genres  \
# 1210                     True              True       Adventure
# 1211                     True              True          Action
#
#       Metadata.Licensed? Metadata.Publishers  Metadata.Sequel?  \
# 1210                True                 NaN              True
# 1211                True                 NaN              True
#
#       Metrics.Review Score  ...  Length.Main + Extras.Average  \
# 1210                    64  ...                          11.5
# 1211                    39  ...                           0.0
#
#       Length.Main + Extras.Leisure Length.Main + Extras.Median  \
# 1210                         11.75                        11.5
# 1211                          0.00                         0.0
#
#      Length.Main + Extras.Polled  Length.Main + Extras.Rushed  \
# 1210                           2                        11.25
# 1211                           0                         0.00
#
#       Length.Main Story.Average  Length.Main Story.Leisure  \
# 1210                        8.8                  12.566667
# 1211                        0.0                   0.000000
#
#       Length.Main Story.Median  Length.Main Story.Polled  \
# 1210                  8.716667                        16
# 1211                  0.000000                         0
#
#       Length.Main Story.Rushed
# 1210                  6.816667
# 1211                  0.000000
#
# [2 rows x 36 columns]

# %%
# Print out summary statistics about the dataframe

video_game_df.describe()
# Out:
#        Features.Max Players  Metrics.Review Score  Metrics.Sales  \
# count           1212.000000           1212.000000     1212.00000
# mean               1.658416             68.828383        0.50316
# std                1.204377             12.956266        1.06985
# min                1.000000             19.000000        0.01000
# 25%                1.000000             60.000000        0.09000
# 50%                1.000000             70.000000        0.21000
# 75%                2.000000             79.000000        0.46000
# max                8.000000             98.000000       14.66000
#
#        Metrics.Used Price  Release.Year  Length.All PlayStyles.Average  \
# count         1212.000000   1212.000000                    1212.000000
# mean            17.393894   2006.820132                      13.653177
# std              5.018972      1.050653                      19.397156
# min              4.950000   2004.000000                       0.000000
# 25%             14.950000   2006.000000                       3.562500
# 50%             17.950000   2007.000000                       8.858333
# 75%             17.950000   2008.000000                      16.033333
# max             49.950000   2008.000000                     279.733333
#
#        Length.All PlayStyles.Leisure  Length.All PlayStyles.Median  \
# count                    1212.000000                   1212.000000
# mean                       26.250426                     11.225371
# std                        51.598941                     13.493717
# min                         0.000000                      0.000000
# 25%                         4.000000                      3.025000
# 50%                        12.000000                      8.000000
# 75%                        27.600000                     13.783333
# max                       476.266667                    126.000000
#
#        Length.All PlayStyles.Polled  Length.All PlayStyles.Rushed  ...  \
# count                   1212.000000                   1212.000000  ...
# mean                      44.415842                      9.396163  ...
# std                      154.837893                     11.176371  ...
# min                        0.000000                      0.000000  ...
# 25%                        1.000000                      2.600000  ...
# 50%                        6.000000                      6.708333  ...
# 75%                       25.000000                     11.366667  ...
# max                     2300.000000                    120.200000  ...
#
#        Length.Main + Extras.Average  Length.Main + Extras.Leisure  \
# count                   1212.000000                   1212.000000
# mean                      12.731491                     18.866048
# std                       23.979610                     42.917021
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        7.291667                      8.000000
# 75%                       16.112500                     21.033333
# max                      291.000000                    478.933333
#
#        Length.Main + Extras.Median  Length.Main + Extras.Polled  \
# count                  1212.000000                  1212.000000
# mean                     12.103548                    13.995875
# std                      23.355374                    57.333257
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       7.000000                     1.000000
# 75%                      15.000000                     7.000000
# max                     291.000000                  1100.000000
#
#        Length.Main + Extras.Rushed  Length.Main Story.Average  \
# count                  1212.000000                1212.000000
# mean                     10.319788                   8.465952
# std                      20.895117                   9.691745
# min                       0.000000                   0.000000
# 25%                       0.000000                   0.000000
# 50%                       6.283333                   6.575000
# 75%                      12.941667                  11.033333
# max                     291.000000                  72.383333
#
#        Length.Main Story.Leisure  Length.Main Story.Median  \
# count                1212.000000               1212.000000
# mean                   11.051966                  8.280941
# std                    14.092617                  9.502600
# min                     0.000000                  0.000000
# 25%                     0.000000                  0.000000
# 50%                     8.000000                  6.041667
# 75%                    14.508333                 10.533333
# max                   135.583333                 70.000000
#
#        Length.Main Story.Polled  Length.Main Story.Rushed
# count               1212.000000               1212.000000
# mean                  24.882838                  6.974697
# std                   87.382770                  7.964522
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    3.000000                  5.341667
# 75%                   14.000000                  9.312500
# max                 1100.000000                 70.000000
#
# [8 rows x 25 columns]

# %%
# Choose a column and print out the column (it's ok if the output is abbreviated)

video_game_df['Release.Year']
# Out:
# 0       2004
# 1       2004
# 2       2004
# 3       2004
# 4       2004
#         ...
# 1207    2008
# 1208    2008
# 1209    2008
# 1210    2008
# 1211    2008
# Name: Release.Year, Length: 1212, dtype: int64

# %%
# Choose a column that has numeric values and make a line plot of the values

ax = video_game_df.plot(y= 'Metrics.Used Price',kind='line')

# %%
# Use "loc" to print out the first 10 elements of the plotted column

video_game_df.loc[0:9]['Metrics.Used Price']
# Out:
# 0    24.95
# 1    14.95
# 2    22.95
# 3    12.95
# 4    14.95
# 5    12.95
# 6    19.95
# 7    17.95
# 8     8.95
# 9    24.95
# Name: Metrics.Used Price, dtype: float64

# %%
# Use "loc" to print out the first 10 elements of the plotted column
# as well as the matching 10 elements of a different column that has interesting text

video_game_df.loc[0:9,['Metrics.Used Price','Metadata.Publishers']]
# Out:
#    Metrics.Used Price Metadata.Publishers
# 0               24.95            Nintendo
# 1               14.95             Ubisoft
# 2               22.95            Nintendo
# 3               12.95                Sony
# 4               14.95          Activision
# 5               12.95                  EA
# 6               19.95               Namco
# 7               17.95              Konami
# 8                8.95                  EA
# 9               24.95            Nintendo

# %%
# Assign the dataframe values from the previous cell into a new dataframe variable
# and make a bar plot with the text values horizontally and the numeric values as the bar heights

video_game_df[:9].plot(kind='bar',
             x='Metadata.Genres',
             y='Metrics.Used Price',
             figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Metadata.Genres'>

# %%
# Re-do the plot from the previous cell as a horizontal bar plot

video_game_df[:9].plot(kind='barh',
             x='Metadata.Genres',
             y='Metrics.Used Price',
             figsize=(12,5))
# Out:
# <AxesSubplot:ylabel='Metadata.Genres'>

# %%
# Re-do the plot from the previous cell
# and change at least two aesthetic elements (colors, labels, titles, ...)

ax = video_game_df[:9].sort_values(by='Metadata.Genres').plot(kind='barh',
             x='Metadata.Genres',
             y='Metrics.Used Price',
             figsize=(12,5),
             color='orange')

ax.set_ylabel('Genres',fontsize=12)
# Out:
# Text(0, 0.5, 'Genres')

# %% [markdown]
# # Free form section

# %% [markdown]
# * Choose another type of plot that interests you from the [pandas.DataFrame.plot documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html#) [look at the 'kind' parameter] and make a new plot of your dataset values using the plot type

# %%
video_game_df[:9].plot(kind='area',
             x='Metadata.Genres',
             y='Metrics.Review Score',
             figsize=(30,5))
# Out:
# <AxesSubplot:xlabel='Metadata.Genres'>

# %% [markdown]
# * Copy some of your analysis from the Week 2 assignment into new cells below
# * Clean them up if desired, and make sure that you translate them to work with your new pandas dataframe structure here if needed
# * Create several plots to complement and extend your analysis

# %%
video_game_df[:50].sort_values(by='Metadata.Genres').plot(kind='bar', 
                                                          x='Metadata.Genres', 
                                                          y='Length.All PlayStyles.Average', 
                                                          figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Metadata.Genres'>

# %%
video_game_df[:50].sort_values(by='Metadata.Genres').plot(kind='bar', 
                                                          x='Title', 
                                                          y='Length.All PlayStyles.Average', 
                                                          figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Title'>
